# %% [markdown]
# # ASR Fine-Tuning at Scale using AWS SageMaker

# %% [markdown]
# In this tutorial we show how you can train a NeMo ASR Model using [Amazon SageMaker](https://docs.aws.amazon.com/sagemaker/latest/dg/whatis.html) using the CommonVoice Esperanto dataset (~250hrs), and scale onto multiple GPUs and nodes with near-linear scaling.
#
# AWS SageMaker is useful for practioners/researchers who are familiar with training locally or on a remote instance (via SSH). SageMaker also supports multi-GPU & Multi-node.

# %% [markdown]
# <img src="images/sagemaker_benchmark.png" alt="sagemaker_benchmark" style="width: 700px;"/>

# %% [markdown]
# We fine-tune the [Conformer SSL Large (En)](https://catalog.ngc.nvidia.com/orgs/nvidia/teams/nemo/models/ssl_en_conformer_large) model using the CommonVoice esperanto subset on a remote instance with a 8 GPUs (ml.p3.16xlarge). We use S3 to store the data and our checkpoints/logs.
#
# The overall steps are:
#
# 1. Setup your AWS Credentials to access SageMaker
# 2. Download the source code we'll be running
# 3. Setup the CommonVoice Esperanto dataset
# 4. Upload data to S3
# 5. Configure the training job
# 6. Run training job on SageMaker
# 7. Download model, (Optional) Tensorboard Logs

# %%
# If you're using Google Colab and not running locally, run this cell.

## Install dependencies
# !pip install wget
# !sudo yum install sox -y
# !sudo yum install libsndfile
# !sudo sh ./packages/ffmpeg/install-ffmpeg-amazon-linux.sh
# !pip install numba==0.53.1
# !pip install text-unidecode
# !pip install matplotlib>=3.3.2
# !pip install sagemaker==2.118.0 awscli sagemaker-training
# !pip install librosa==0.9.2

BRANCH = 'main'
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[all]
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=1e98396b530999c3aac273a01295e5c9506fa45256642ba5529b42bb90a0f003
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/ba/78/fb/e0c24a9e73d7483b073d15b7e05f43f3fc2ac75eff6899c7aa
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# amzn2-core                                               | 3.7 kB     00:00
# amzn2extra-docker                                        | 3.0 kB     00:00
# amzn2extra-kernel-5.10                                   | 3.0 kB     00:00
# amzn2extra-python3.8                                     | 3.0 kB     00:00
# centos-extras                                            | 2.9 kB     00:00
# copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxi | 3.3 kB     00:00
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# libnvidia-container/x86_64/signature                     |  833 B     00:00
# libnvidia-container/x86_64/signature                     | 2.1 kB     00:00 !!!
# neuron                                                   | 2.9 kB     00:00
# neuron/primary_db                                          | 111 kB   00:02
# 61 packages excluded due to repository priority protections
# Resolving Dependencies
# --> Running transaction check
# ---> Package sox.x86_64 0:14.4.1-7.amzn2 will be installed
# --> Processing Dependency: libpulse.so.0(PULSE_0)(64bit) for package: sox-14.4.1-7.amzn2.x86_64
# --> Processing Dependency: libpulse-simple.so.0(PULSE_0)(64bit) for package: sox-14.4.1-7.amzn2.x86_64
# --> Processing Dependency: libao.so.4(LIBAO4_1.1.0)(64bit) for package: sox-14.4.1-7.amzn2.x86_64
# --> Processing Dependency: libwavpack.so.1()(64bit) for package: sox-14.4.1-7.amzn2.x86_64
# --> Processing Dependency: libpulse.so.0()(64bit) for package: sox-14.4.1-7.amzn2.x86_64
# --> Processing Dependency: libpulse-simple.so.0()(64bit) for package: sox-14.4.1-7.amzn2.x86_64
# --> Processing Dependency: libao.so.4()(64bit) for package: sox-14.4.1-7.amzn2.x86_64
# --> Running transaction check
# ---> Package libao.x86_64 0:1.1.0-8.amzn2.0.2 will be installed
# ---> Package pulseaudio-libs.x86_64 0:10.0-3.amzn2.0.3 will be installed
# --> Processing Dependency: libasyncns.so.0()(64bit) for package: pulseaudio-libs-10.0-3.amzn2.0.3.x86_64
# ---> Package wavpack.x86_64 0:4.60.1-9.amzn2.0.1 will be installed
# --> Running transaction check
# ---> Package libasyncns.x86_64 0:0.8-7.amzn2.0.2 will be installed
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package              Arch        Version                 Repository       Size
# ================================================================================
# Installing:
#  sox                  x86_64      14.4.1-7.amzn2          amzn2-core      401 k
# Installing for dependencies:
#  libao                x86_64      1.1.0-8.amzn2.0.2       amzn2-core       72 k
#  libasyncns           x86_64      0.8-7.amzn2.0.2         amzn2-core       26 k
#  pulseaudio-libs      x86_64      10.0-3.amzn2.0.3        amzn2-core      648 k
#  wavpack              x86_64      4.60.1-9.amzn2.0.1      amzn2-core      132 k
#
# Transaction Summary
# ================================================================================
# Install  1 Package (+4 Dependent packages)
#
# Total download size: 1.2 M
# Installed size: 4.8 M
# Downloading packages:
# (1/5): libasyncns-0.8-7.amzn2.0.2.x86_64.rpm               |  26 kB   00:00
# (2/5): libao-1.1.0-8.amzn2.0.2.x86_64.rpm                  |  72 kB   00:00
# (3/5): pulseaudio-libs-10.0-3.amzn2.0.3.x86_64.rpm         | 648 kB   00:00
# (4/5): sox-14.4.1-7.amzn2.x86_64.rpm                       | 401 kB   00:00
# (5/5): wavpack-4.60.1-9.amzn2.0.1.x86_64.rpm               | 132 kB   00:00
# --------------------------------------------------------------------------------
# Total                                              2.9 MB/s | 1.2 MB  00:00
# Running transaction check
# Running transaction test
# Transaction test succeeded
# Running transaction
# Warning: RPMDB altered outside of yum.
#   Installing : wavpack-4.60.1-9.amzn2.0.1.x86_64                            1/5
#   Installing : libasyncns-0.8-7.amzn2.0.2.x86_64                            2/5
#   Installing : pulseaudio-libs-10.0-3.amzn2.0.3.x86_64                      3/5
#   Installing : libao-1.1.0-8.amzn2.0.2.x86_64                               4/5
#   Installing : sox-14.4.1-7.amzn2.x86_64                                    5/5
#   Verifying  : libasyncns-0.8-7.amzn2.0.2.x86_64                            1/5
#   Verifying  : sox-14.4.1-7.amzn2.x86_64                                    2/5
#   Verifying  : libao-1.1.0-8.amzn2.0.2.x86_64                               3/5
#   Verifying  : pulseaudio-libs-10.0-3.amzn2.0.3.x86_64                      4/5
#   Verifying  : wavpack-4.60.1-9.amzn2.0.1.x86_64                            5/5
#
# Installed:
#   sox.x86_64 0:14.4.1-7.amzn2
#
# Dependency Installed:
#   libao.x86_64 0:1.1.0-8.amzn2.0.2          libasyncns.x86_64 0:0.8-7.amzn2.0.2
#   pulseaudio-libs.x86_64 0:10.0-3.amzn2.0.3 wavpack.x86_64 0:4.60.1-9.amzn2.0.1
#
# Complete!
# Loaded plugins: dkms-build-requires, extras_suggestions, langpacks, priorities,
#               : update-motd, versionlock
# Existing lock /var/run/yum.pid: another copy is running as pid 9798.
# Another app is currently holding the yum lock; waiting for it to exit...
#   The other application is: yum
#     Memory :  46 M RSS (262 MB VSZ)
#     Started: Fri Mar 10 09:35:33 2023 - 00:00 ago
#     State  : Running, pid: 9798
# amzn2-core                                               | 3.7 kB     00:00
# amzn2extra-docker                                        | 3.0 kB     00:00
# amzn2extra-kernel-5.10                                   | 3.0 kB     00:00
# amzn2extra-python3.8                                     | 3.0 kB     00:00
# centos-extras                                            | 2.9 kB     00:00
# copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxi | 3.3 kB     00:00
# https://download.docker.com/linux/centos/2/x86_64/stable/repodata/repomd.xml: [Errno 14] HTTPS Error 404 - Not Found
# Trying other mirror.
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxall_vmafv2.pkl.model
# ffmpeg-4.2.1-amd64-static/model/other_models/vmaf_v0.6.0.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/nflx_vmaff_rf_v2.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxtrain_vmafv2.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxtrain_vmafv3.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/niqe_v0.1.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxtrain_libsvmnusvr_currentbest.pkl.model
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxall_vmafv3.pkl.model
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxall_vmafv1.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/nflx_v1.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/vmaf_4k_v0.6.1rc.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxall_vmafv4.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/vmaf_4k_v0.6.1rc.pkl.model
# ffmpeg-4.2.1-amd64-static/model/other_models/nflx_v1.pkl.model
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxtrain_vmafv1.pkl.model
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxall_vmafv4.pkl.model
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxtrain_vmafv1.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxall_libsvmnusvr_currentbest.pkl.model
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxtrain_vmafv3a.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxtrain_vmafv3.pkl.model
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxtrain_norm_type_none.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/vmaf_v0.6.0.pkl.model
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxall_vmafv3a.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxall_vmafv1.pkl.model
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxall_vmafv3.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxtrain_libsvmnusvr_currentbest.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxall_libsvmnusvr_currentbest.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/nflx_vmaff_rf_v1.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxtrain_vmafv2.pkl.model
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxall_vmafv2.pkl
# ffmpeg-4.2.1-amd64-static/model/other_models/model_V8a.model
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxtrain_norm_type_none.pkl.model
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxtrain_vmafv3a.pkl.model
# ffmpeg-4.2.1-amd64-static/model/other_models/nflxall_vmafv3a.pkl.model
# ffmpeg-4.2.1-amd64-static/model/vmaf_4k_v0.6.1.pkl.model
# ffmpeg-4.2.1-amd64-static/model/vmaf_v0.6.1.pkl
# ffmpeg-4.2.1-amd64-static/readme.txt
# ffmpeg-4.2.1-amd64-static/ffmpeg
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting numba==0.53.1
#   Downloading numba-0.53.1-cp39-cp39-manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 27.5 MB/s eta 0:00:00:00:01
# Requirement already satisfied: numpy>=1.15 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from numba==0.53.1) (1.23.5)
# Collecting llvmlite<0.37,>=0.36.0rc1
#   Downloading llvmlite-0.36.0-cp39-cp39-manylinux2010_x86_64.whl (25.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 77.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from numba==0.53.1) (65.6.3)
# Installing collected packages: llvmlite, numba
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.39.1
#     Uninstalling llvmlite-0.39.1:
#       Successfully uninstalled llvmlite-0.39.1
#   Attempting uninstall: numba
#     Found existing installation: numba 0.56.4
#     Uninstalling numba-0.56.4:
#       Successfully uninstalled numba-0.56.4
# Successfully installed llvmlite-0.36.0 numba-0.53.1
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: text-unidecode in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (1.3)
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting sagemaker==2.118.0
#   Downloading sagemaker-2.118.0.tar.gz (614 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.0/615.0 kB 7.4 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: awscli in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (1.27.71)
# Collecting sagemaker-training
#   Downloading sagemaker_training-4.4.8.tar.gz (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 15.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: attrs<23,>=20.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker==2.118.0) (22.2.0)
# Requirement already satisfied: boto3<2.0,>=1.26.20 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker==2.118.0) (1.26.71)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker==2.118.0) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker==2.118.0) (1.23.5)
# Requirement already satisfied: protobuf<4.0,>=3.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker==2.118.0) (3.20.2)
# Requirement already satisfied: protobuf3-to-dict<1.0,>=0.1.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker==2.118.0) (0.1.5)
# Requirement already satisfied: smdebug_rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker==2.118.0) (1.0.1)
# Requirement already satisfied: importlib-metadata<5.0,>=1.4.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker==2.118.0) (4.13.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker==2.118.0) (21.3)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker==2.118.0) (1.4.4)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker==2.118.0) (0.3.0)
# Requirement already satisfied: schema in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker==2.118.0) (0.7.5)
# Requirement already satisfied: botocore==1.29.71 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from awscli) (1.29.71)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from awscli) (4.7.2)
# Requirement already satisfied: docutils<0.17,>=0.10 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from awscli) (0.15.2)
# Requirement already satisfied: PyYAML<5.5,>=3.10 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from awscli) (5.4.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from awscli) (0.6.0)
# Requirement already satisfied: colorama<0.4.5,>=0.2.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from awscli) (0.4.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from botocore==1.29.71->awscli) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from botocore==1.29.71->awscli) (1.26.8)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from botocore==1.29.71->awscli) (1.0.1)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker-training) (1.16.0)
# Requirement already satisfied: pip in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker-training) (22.3.1)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: gevent in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker-training) (22.10.2)
# Collecting inotify_simple==1.2.1
#   Downloading inotify_simple-1.2.1.tar.gz (7.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: werkzeug>=0.15.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker-training) (2.2.2)
# Requirement already satisfied: paramiko>=2.4.2 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker-training) (3.0.0)
# Requirement already satisfied: psutil>=5.6.7 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker-training) (5.9.4)
# Requirement already satisfied: scipy>=1.2.2 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sagemaker-training) (1.8.1)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from importlib-metadata<5.0,>=1.4.0->sagemaker==2.118.0) (3.11.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from packaging>=20.0->sagemaker==2.118.0) (3.0.9)
# Requirement already satisfied: bcrypt>=3.2 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from paramiko>=2.4.2->sagemaker-training) (4.0.1)
# Requirement already satisfied: cryptography>=3.3 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from paramiko>=2.4.2->sagemaker-training) (39.0.0)
# Requirement already satisfied: pynacl>=1.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from paramiko>=2.4.2->sagemaker-training) (1.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from rsa<4.8,>=3.1.2->awscli) (0.4.8)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from werkzeug>=0.15.5->sagemaker-training) (2.1.1)
# Requirement already satisfied: zope.interface in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from gevent->sagemaker-training) (5.5.2)
# Requirement already satisfied: greenlet>=2.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from gevent->sagemaker-training) (2.0.1)
# Requirement already satisfied: zope.event in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from gevent->sagemaker-training) (4.6)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from gevent->sagemaker-training) (65.6.3)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pandas->sagemaker==2.118.0) (2022.7)
# Requirement already satisfied: pox>=0.3.2 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pathos->sagemaker==2.118.0) (0.3.2)
# Requirement already satisfied: ppft>=1.7.6.6 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pathos->sagemaker==2.118.0) (1.7.6.6)
# Requirement already satisfied: multiprocess>=0.70.14 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pathos->sagemaker==2.118.0) (0.70.14)
# Requirement already satisfied: dill>=0.3.6 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pathos->sagemaker==2.118.0) (0.3.6)
# Requirement already satisfied: contextlib2>=0.5.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from schema->sagemaker==2.118.0) (21.6.0)
# Requirement already satisfied: cffi>=1.12 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from cryptography>=3.3->paramiko>=2.4.2->sagemaker-training) (1.15.1)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko>=2.4.2->sagemaker-training) (2.21)
# Building wheels for collected packages: sagemaker, sagemaker-training, inotify_simple
#   Building wheel for sagemaker (setup.py) ... done
#   Created wheel for sagemaker: filename=sagemaker-2.118.0-py2.py3-none-any.whl size=836938 sha256=6b8afd4c0358133b64b9c94e8e06d3464d9a0575ec1619c050c817cf4d1b26ec
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/ce/23/58/9c455c4ab74ae673f7ec92a84318e2599a54ec4c7adee389ae
#   Building wheel for sagemaker-training (setup.py) ... done
#   Created wheel for sagemaker-training: filename=sagemaker_training-4.4.8-cp39-cp39-linux_x86_64.whl size=77008 sha256=ea5137fe6ece5aee04ee674cf5c40017c670bf30fd2fc1709af91b04096f3788
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/94/19/d6/96061cb58382daef353286217394c9438cd7b6212c5894b0e6
#   Building wheel for inotify_simple (setup.py) ... done
#   Created wheel for inotify_simple: filename=inotify_simple-1.2.1-py3-none-any.whl size=8201 sha256=2c016b94b05e8cce3a87fd9d3f699a4664f350c2b5a33c4ee6b873653a28bb5e
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/3f/c2/6a/6f6c65836d2fad9ae7008373d82e38b519187113fac6b720c8
# Successfully built sagemaker sagemaker-training inotify_simple
# Installing collected packages: inotify_simple, retrying, sagemaker-training, sagemaker
#   Attempting uninstall: sagemaker
#     Found existing installation: sagemaker 2.132.0
#     Uninstalling sagemaker-2.132.0:
#       Successfully uninstalled sagemaker-2.132.0
# Successfully installed inotify_simple-1.2.1 retrying-1.3.4 sagemaker-2.118.0 sagemaker-training-4.4.8
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting librosa==0.9.2
#   Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 2.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: scipy>=1.2.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from librosa==0.9.2) (1.8.1)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 5.0 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pooch>=1.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from librosa==0.9.2) (1.6.0)
# Requirement already satisfied: decorator>=4.0.10 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from librosa==0.9.2) (5.1.1)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from librosa==0.9.2) (21.3)
# Requirement already satisfied: joblib>=0.14 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from librosa==0.9.2) (1.2.0)
# Collecting soundfile>=0.10.2
#   Downloading soundfile-0.12.1-py2.py3-none-any.whl (24 kB)
# Collecting resampy>=0.2.2
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 33.4 MB/s eta 0:00:00:00:01
# Requirement already satisfied: scikit-learn>=0.19.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from librosa==0.9.2) (1.0)
# Requirement already satisfied: numba>=0.45.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from librosa==0.9.2) (0.53.1)
# Requirement already satisfied: numpy>=1.17.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from librosa==0.9.2) (1.23.5)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from numba>=0.45.1->librosa==0.9.2) (0.36.0)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from numba>=0.45.1->librosa==0.9.2) (65.6.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from packaging>=20.0->librosa==0.9.2) (3.0.9)
# Requirement already satisfied: requests>=2.19.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pooch>=1.0->librosa==0.9.2) (2.28.1)
# Requirement already satisfied: appdirs>=1.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pooch>=1.0->librosa==0.9.2) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from scikit-learn>=0.19.1->librosa==0.9.2) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from soundfile>=0.10.2->librosa==0.9.2) (1.15.1)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.9.2) (2.21)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (1.26.8)
# Building wheels for collected packages: audioread
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23704 sha256=6c71216d35fd52bdb534a0c1f5098a86971d79159a96e7905f501fe9a59f7bb4
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/7a/6a/b0/92760a6d6bc2bff5464970af910c0b0b921390993f3199cdf7
# Successfully built audioread
# Installing collected packages: audioread, soundfile, resampy, librosa
# Successfully installed audioread-3.0.0 librosa-0.9.2 resampy-0.4.2 soundfile-0.12.1
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting nemo_toolkit[all]
#   Cloning https://github.com/NVIDIA/NeMo.git (to revision main) to /tmp/pip-install-ndwnxlpy/nemo-toolkit_703928072c134b598d9d3b2a71b7c7f7
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA/NeMo.git /tmp/pip-install-ndwnxlpy/nemo-toolkit_703928072c134b598d9d3b2a71b7c7f7
#   Resolved https://github.com/NVIDIA/NeMo.git to commit ff501bd8e3991ca85ebd02834eadd3d1e3198f42
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: text-unidecode in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (1.3)
# Requirement already satisfied: numpy>=1.22 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (1.23.5)
# Requirement already satisfied: numba in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (0.53.1)
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.13.1-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 kB 3.9 MB/s eta 0:00:0000:01
# Collecting setuptools==59.5.0
#   Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 kB 7.9 MB/s eta 0:00:0000:01
# Requirement already satisfied: scikit-learn in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (1.0)
# Collecting tensorboard
#   Downloading tensorboard-2.12.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 20.2 MB/s eta 0:00:0000:01:00:01
# Requirement already satisfied: torch in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (1.13.1)
# Requirement already satisfied: onnx>=1.7.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (1.11.0)
# Requirement already satisfied: python-dateutil in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (2.8.2)
# Requirement already satisfied: wget in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (3.2)
# Requirement already satisfied: tqdm>=4.41.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (4.63.2)
# Requirement already satisfied: wrapt in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (1.14.1)
# Requirement already satisfied: ruamel.yaml in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (0.17.21)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting youtokentome>=1.0.5
#   Downloading youtokentome-1.0.6.tar.gz (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting g2p-en
#   Downloading g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 40.5 MB/s eta 0:00:00:00:01
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (21.3)
# Requirement already satisfied: h5py in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (3.7.0)
# Collecting parameterized
#   Downloading parameterized-0.8.1-py2.py3-none-any.whl (26 kB)
# Collecting rapidfuzz
#   Downloading rapidfuzz-2.13.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 44.3 MB/s eta 0:00:00:00:01
# Collecting pytorch-lightning>=1.9.0
#   Downloading pytorch_lightning-1.9.4-py3-none-any.whl (827 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.8/827.8 kB 22.5 MB/s eta 0:00:0000:01
# Requirement already satisfied: boto3 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (1.26.71)
# Collecting sphinxcontrib-bibtex
#   Downloading sphinxcontrib_bibtex-2.5.0-py3-none-any.whl (39 kB)
# Collecting jieba
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 32.1 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting kaldi-python-io
#   Downloading kaldi-python-io-1.2.2.tar.gz (8.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sphinx in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (5.1.1)
# Collecting einops
#   Downloading einops-0.6.0-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 14.3 MB/s eta 0:00:00
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.7.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 28.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: soundfile in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (0.12.1)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: isort<6.0.0,>5.1.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (5.11.4)
# Collecting braceexpand
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Collecting omegaconf<2.3,>=2.2
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 19.0 MB/s eta 0:00:00
# Collecting pytest-runner
#   Using cached pytest_runner-6.0.0-py3-none-any.whl (7.2 kB)
# Collecting attrdict
#   Downloading attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Collecting pyannote.core
#   Downloading pyannote.core-5.0.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 18.4 MB/s eta 0:00:00
# Collecting transformers>=4.0.1
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 49.0 MB/s eta 0:00:00:00:01
# Requirement already satisfied: flask-restful in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (0.3.9)
# Collecting jiwer
#   Downloading jiwer-2.5.1-py3-none-any.whl (15 kB)
# Collecting editdistance
#   Downloading editdistance-0.6.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.4/282.4 kB 66.5 MB/s eta 0:00:00
# Collecting gradio
#   Downloading gradio-3.20.1-py3-none-any.whl (14.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 34.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: ipywidgets in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (8.0.4)
# Collecting pangu
#   Downloading pangu-4.0.6.1-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: scipy>=0.14 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (1.8.1)
# Collecting kaldiio
#   Downloading kaldiio-2.17.2.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Collecting marshmallow
#   Downloading marshmallow-3.19.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: nltk in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (3.8.1)
# Requirement already satisfied: librosa in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (0.9.2)
# Collecting sox
#   Downloading sox-1.4.1-py2.py3-none-any.whl (39 kB)
# Collecting ijson
#   Downloading ijson-3.2.0.post0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 21.6 MB/s eta 0:00:00
# Collecting black==19.10b0
#   Downloading black-19.10b0-py36-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 27.2 MB/s eta 0:00:00
# Requirement already satisfied: pytest in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from nemo_toolkit[all]) (7.2.0)
# ...
# Requirement already satisfied: debugpy>=1.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (1.6.5)
# Requirement already satisfied: nest-asyncio in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (1.5.5)
# Requirement already satisfied: pyzmq>=17 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (6.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (7.4.8)
# Requirement already satisfied: comm>=0.1.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (3.0.36)
# Requirement already satisfied: pickleshare in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (0.18.2)
# Requirement already satisfied: backcall in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (4.8.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting linkify-it-py<3,>=1
#   Downloading linkify_it_py-2.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: typer[all]>=0.2.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.4.2)
# Collecting latexcodec>=1.0.4
#   Downloading latexcodec-2.0.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from requests->transformers>=4.0.1->nemo_toolkit[all]) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from requests->transformers>=4.0.1->nemo_toolkit[all]) (3.4)
# Collecting urllib3<1.27,>=1.25.4
#   Using cached urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from sympy>=1.1->pyannote.metrics->nemo_toolkit[all]) (1.2.1)
# Requirement already satisfied: soupsieve>1.2 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from beautifulsoup4->gdown->nemo_toolkit[all]) (2.3.2.post1)
# Collecting starlette<0.26.0,>=0.25.0
#   Downloading starlette-0.25.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 21.9 MB/s eta 0:00:00
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: sniffio in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from httpx->gradio->nemo_toolkit[all]) (1.3.0)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 23.8 MB/s eta 0:00:00
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from requests->transformers>=4.0.1->nemo_toolkit[all]) (1.7.1)
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 20.2 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from httpcore<0.17.0,>=0.15.0->httpx->gradio->nemo_toolkit[all]) (3.6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (0.8.3)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->nemo_toolkit[all]) (0.19.3)
# Requirement already satisfied: jupyter-core>=4.9.2 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (5.1.3)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[all]) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 3.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (1.5.0.post1)
# Requirement already satisfied: platformdirs>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (2.6.2)
# Building wheels for collected packages: antlr4-python3-runtime, progress, sacremoses, youtokentome, fasttext, jieba, kaldi-python-io, kaldiio, nemo_toolkit, sentence-transformers, distance, ipadic, cdifflib, ffmpy, pathtools
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=7311d54dfde7b4c419b8914354876352754a18a0c45497bc58410991856e6493
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/a7/72/3e/7d4bb4df2f34e8a15d0d764bb98e7ca19a765483710646a8b3
#   Building wheel for progress (setup.py) ... done
#   Created wheel for progress: filename=progress-1.6-py3-none-any.whl size=9611 sha256=b4f750161a2ff40347625ada74cb05260e0b3704aca898ce37e6b94f521fab1a
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/75/d9/93/1e85a94fd6347c86dd3e46b5f59669f30e2e8cbd4f963849a3
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895241 sha256=b08ea147cef1141ae5e8a551e288efb8efb203745f543ac0b1e19f8bed8cf8ff
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/42/79/78/5ad3b042cb2d97c294535162cdbaf9b167e3b186eae55ab72d
#   Building wheel for youtokentome (setup.py) ... done
#   Created wheel for youtokentome: filename=youtokentome-1.0.6-cp39-cp39-linux_x86_64.whl size=161353 sha256=848f74e3309219f63d38959fa1ca87061b41ec2b529889fcf5f563b1d137376b
#   Stored in directory: /home/ec2-user/.cache/pip/wheels
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=cb0ddbef15f356205149c66013035eb6fb2dc18fb921775a60075ed6fb610f7a
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/20/7c/09/4ad42725a29fce4bc21137c7f25f062b3655a4aea5b0e8d9a2
# Successfully built antlr4-python3-runtime progress sacremoses youtokentome fasttext jieba kaldi-python-io kaldiio nemo_toolkit sentence-transformers distance ipadic cdifflib ffmpy pathtools
# Installing collected packages: tokenizers, tensorboard-plugin-wit, sentencepiece, rfc3986, pydub, progress, plac, pathtools, parameterized, pangu, opencc, mecab-python3, jieba, ipadic, ijson, ffmpy, faiss-cpu, distance, braceexpand, antlr4-python3-runtime, websockets, webdataset, urllib3, uc-micro-py, tensorboard-data-server, sox, smmap, setuptools, setproctitle, rapidfuzz, python-multipart, pytest-runner, pypinyin, pynini, pyasn1-modules, portalocker, orjson, omegaconf, oauthlib, mdurl, lxml, loguru, latexcodec, kaldiio, kaldi-python-io, h11, grpcio, ftfy, einops, editdistance, docker-pycreds, click, cdifflib, cachetools, attrdict, aiofiles, absl-py, youtokentome, uvicorn, torchmetrics, starlette, sentry-sdk, sacremoses, sacrebleu, pypinyin-dict, pybtex, pyannote.core, marshmallow, markdown-it-py, markdown, linkify-it-py, lightning-utilities, levenshtein, kornia, inflect, hydra-core, httpcore, google-auth, gitdb, fasttext, black, texterrors, requests-oauthlib, pybtex-docutils, mdit-py-plugins, jiwer, huggingface-hub, httpx, GitPython, g2p-en, fastapi, altair, wandb, transformers, sphinxcontrib-bibtex, pytorch-lightning, pyannote.database, gradio, google-auth-oauthlib, gdown, tensorboard, sentence-transformers, pyannote.metrics, nemo-text-processing, nemo_toolkit
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.8
#     Uninstalling urllib3-1.26.8:
#       Successfully uninstalled urllib3-1.26.8
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.6.3
#     Uninstalling setuptools-65.6.3:
#       Successfully uninstalled setuptools-65.6.3
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
#   Attempting uninstall: black
#     Found existing installation: black 22.10.0
#     Uninstalling black-22.10.0:
#       Successfully uninstalled black-22.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# python-lsp-black 1.2.1 requires black>=22.3.0, but you have black 19.10b0 which is incompatible.
# jupyterlab-server 2.18.0 requires jsonschema>=4.17.3, but you have jsonschema 3.2.0 which is incompatible.
# distributed 2022.11.0 requires tornado<6.2,>=6.0.3, but you have tornado 6.2 which is incompatible.
# Successfully installed GitPython-3.1.31 absl-py-1.4.0 aiofiles-23.1.0 altair-4.2.2 antlr4-python3-runtime-4.9.3 attrdict-2.0.1 black-19.10b0 braceexpand-0.1.7 cachetools-5.3.0 cdifflib-1.2.6 click-8.0.2 distance-0.1.3 docker-pycreds-0.4.0 editdistance-0.6.2 einops-0.6.0 faiss-cpu-1.7.3 fastapi-0.93.0 fasttext-0.9.2 ffmpy-0.3.0 ftfy-6.1.1 g2p-en-2.1.0 gdown-4.6.4 gitdb-4.0.10 google-auth-2.16.2 google-auth-oauthlib-0.4.6 gradio-3.20.1 grpcio-1.51.3 h11-0.14.0 httpcore-0.16.3 httpx-0.23.3 huggingface-hub-0.13.1 hydra-core-1.2.0 ijson-3.2.0.post0 inflect-6.0.2 ipadic-1.0.0 jieba-0.42.1 jiwer-2.5.1 kaldi-python-io-1.2.2 kaldiio-2.17.2 kornia-0.6.10 latexcodec-2.0.1 levenshtein-0.20.2 lightning-utilities-0.7.1 linkify-it-py-2.0.0 loguru-0.6.0 lxml-4.9.2 markdown-3.4.1 markdown-it-py-2.2.0 marshmallow-3.19.0 mdit-py-plugins-0.3.3 mdurl-0.1.2 mecab-python3-1.0.5 nemo-text-processing-0.1.6rc0 nemo_toolkit-1.17.0rc0 oauthlib-3.2.2 omegaconf-2.2.3 opencc-1.1.6 orjson-3.8.7 pangu-4.0.6.1 parameterized-0.8.1 pathtools-0.1.2 plac-1.3.5 portalocker-2.7.0 progress-1.6 pyannote.core-5.0.0 pyannote.database-4.1.3 pyannote.metrics-3.2.1 pyasn1-modules-0.2.8 pybtex-0.24.0 pybtex-docutils-1.0.2 pydub-0.25.1 pynini-2.1.5 pypinyin-0.48.0 pypinyin-dict-0.5.0 pytest-runner-6.0.0 python-multipart-0.0.6 pytorch-lightning-1.9.4 rapidfuzz-2.13.7 requests-oauthlib-1.3.1 rfc3986-1.5.0 sacrebleu-2.3.1 sacremoses-0.0.53 sentence-transformers-2.2.2 sentencepiece-0.1.97 sentry-sdk-1.16.0 setproctitle-1.3.2 setuptools-59.5.0 smmap-5.0.0 sox-1.4.1 sphinxcontrib-bibtex-2.5.0 starlette-0.25.0 tensorboard-2.12.0 tensorboard-data-server-0.7.0 tensorboard-plugin-wit-1.8.1 texterrors-0.4.4 tokenizers-0.13.2 torchmetrics-0.11.3 transformers-4.26.1 uc-micro-py-1.0.1 urllib3-1.26.14 uvicorn-0.21.0 wandb-0.13.11 webdataset-0.1.62 websockets-10.4 youtokentome-1.0.6

# %%
#pip install sagemaker awscli

# %% [markdown]
# ### 1. Setup SageMaker with AWS Credentials
#
# If you haven't setup your AWS credentials, you can setup using the AWS CLI.
# You will need your access and Secret key, with permissions to use SageMaker and S3.

# %%
#!aws configure

# %%
# %load_ext tensorboard
from pathlib import Path
import os
import sagemaker
import wget
import json
import re

from tqdm import tqdm
from omegaconf import OmegaConf
from sagemaker import get_execution_role
from sagemaker.pytorch import PyTorch

# %%
sess = sagemaker.Session()

# %% [markdown]
# ### 2. Download the NeMo source code
#
# SageMaker allows you to pass in your own source code, with an entrypoint script.
#
# Below we download the AWS NeMo `config.yaml` which contains our configuration, and the `speech_to_text_ctc_bpe.py` script to run training.
#
# Our folder structure will look like this:
#
#     code/
#         speech_to_text_ctc_bpe.py
#         conf/
#             config.yaml
#     data/
#         manifests/
#         raw_data/

# %%
root_dir = Path('./')
code_dir = root_dir / 'code/'
config_dir = code_dir / 'conf/'
data_dir = root_dir / 'data/'

root_dir.mkdir(exist_ok=True)
code_dir.mkdir(exist_ok=True)
config_dir.mkdir(exist_ok=True)
data_dir.mkdir(exist_ok=True)

# %%
config_path = str(config_dir / "config.yaml")

# download scripts to format the data source.
wget.download("https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/speech_recognition/convert_hf_dataset_to_nemo.py", str(code_dir))
wget.download("https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/speech_recognition/convert_to_tarred_audio_dataset.py",
              str(code_dir))

# download scripts to run training
wget.download("https://raw.githubusercontent.com/NVIDIA/NeMo/main/examples/asr/conf/conformer/conformer_ctc_bpe.yaml", config_path)
wget.download("https://raw.githubusercontent.com/NVIDIA/NeMo/main/examples/asr/asr_ctc/speech_to_text_ctc_bpe.py",
              str(code_dir))

# download script to create tokenizer
wget.download("https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tokenizers/process_asr_text_tokenizer.py",
              str(code_dir))
# Out:
# 'code/process_asr_text_tokenizer.py'

# %% [markdown]
# We also create a `requirements.txt` file within our source code to install NeMo.

# %%
with open(code_dir / 'requirements.txt', 'w') as f:
    f.write("nemo_toolkit[all]")

# %% [markdown]
# ### 2.1 Initialize SageMaker within Training Script
#
# We provide a helper function that we require to be imported and run at the top of the training script.
#
# This installs and setups DDP for you. It also alleviates having to import a custom container, and can leverage all of the SageMaker containers. Rather than running this cell, you could also manually do this in your script.

# %%
line = "from nemo.utils.cloud import initialize_sagemaker; initialize_sagemaker()"
with open(code_dir / "speech_to_text_ctc.py", 'r+') as f:
    content = f.read()
    f.seek(0, 0)
    f.write(line.rstrip('\r\n') + '\n' + content)

# %% [markdown]
# ### 3. Setup the CommonVoice Esperanto Dataset
#
# Mozilla Common Voice requires you to use huggingface datasets (`pip install datasets`) and register as a user to generate an API key.
#
# #### Authenticated Setup Steps
#
# Website steps:
# - Visit https://huggingface.co/settings/profile
# - Visit "Access Tokens" on list of items.
# - Create new token - provide a name for the token and "read" access is sufficient.
#   - PRESERVE THAT TOKEN API KEY. You can copy that key for next step.
# - Visit the HuggingFace Dataset page for Mozilla Common Voice
#   - There should be a section that asks you for your approval.
#   - Make sure you are logged in and then read that agreement.
#   - If and only if you agree to the text, then accept the terms.

# %%
# Paste your preserved HF TOKEN API KEY (from above) when asked.
# !huggingface-cli login --token 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
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid.
# Your token has been saved to /home/ec2-user/.cache/huggingface/token
# Login successful

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting datasets
#   Downloading datasets-2.10.1-py3-none-any.whl (469 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from datasets) (21.3)
# Requirement already satisfied: requests>=2.19.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from datasets) (2.28.1)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 3.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from datasets) (2022.11.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: aiohttp in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from datasets) (3.8.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from datasets) (0.13.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyyaml>=5.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from datasets) (5.4.1)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from datasets) (1.4.4)
# Requirement already satisfied: numpy>=1.17 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from datasets) (1.23.5)
# Requirement already satisfied: multiprocess in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: tqdm>=4.62.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from datasets) (4.63.2)
# Requirement already satisfied: pyarrow>=6.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from datasets) (10.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.4.0)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from pandas->datasets) (2022.7)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, responses, datasets
# Successfully installed datasets-2.10.1 responses-0.18.0 xxhash-3.2.0

# %% [markdown]
# Now you should be logged in. When running the script, dont forget to set `use_auth_token=True`!

# %%
# !python ./code/convert_hf_dataset_to_nemo.py \
    output_dir=./data/ \
    path="mozilla-foundation/common_voice_11_0" \
    name="eo" \
    ensure_ascii=False \
    use_auth_token=True
# Out:
# /home/ec2-user/SageMaker/NeMo-test/./code/convert_hf_dataset_to_nemo.py:346: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_name='hfds_config', config_path=None)
# /home/ec2-user/anaconda3/envs/pytorch_p39/lib/python3.9/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/next/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# Downloading builder script: 100%|██████████| 8.30k/8.30k [00:00<00:00, 7.66MB/s]
# Downloading readme: 100%|██████████████████| 14.4k/14.4k [00:00<00:00, 12.7MB/s]
# Downloading extra modules: 100%|███████████| 3.44k/3.44k [00:00<00:00, 3.36MB/s]
# Downloading extra modules: 100%|████████████| 60.9k/60.9k [00:00<00:00, 347kB/s]
# Downloading and preparing dataset common_voice_11_0/eo to /home/ec2-user/.cache/huggingface/datasets/mozilla-foundation___common_voice_11_0/eo/11.0.0/2c65b95d99ca879b1b1074ea197b65e0497848fd697fdb0582e0f6b75b6f4da0...
# Downloading data: 100%|████████████████████| 12.2k/12.2k [00:00<00:00, 9.84MB/s]
# Downloading data files:   0%|                             | 0/5 [00:00<?, ?it/s]
# Downloading data:   0%|                             | 0.00/1.62G [00:00<?, ?B/s]
# Downloading data:   0%|                   | 17.4k/1.62G [00:00<4:25:19, 102kB/s]
# Downloading data:   0%|                   | 50.2k/1.62G [00:00<2:56:31, 153kB/s]
# Downloading data:   0%|                    | 137k/1.62G [00:00<1:26:35, 311kB/s]
# Downloading data:   0%|                      | 311k/1.62G [00:00<46:13, 583kB/s]
# Downloading data:   0%|                     | 659k/1.62G [00:00<24:38, 1.09MB/s]
# Downloading data:   0%|                    | 1.34M/1.62G [00:01<13:11, 2.04MB/s]
# Downloading data:   0%|                    | 2.71M/1.62G [00:01<06:49, 3.95MB/s]
# Downloading data:   0%|                    | 5.45M/1.62G [00:01<03:29, 7.70MB/s]
# Downloading data:   1%|                    | 9.45M/1.62G [00:01<02:09, 12.4MB/s]
# Downloading data:   1%|▏                   | 13.4M/1.62G [00:01<01:43, 15.5MB/s]
# Downloading data:   1%|▏                   | 17.3M/1.62G [00:01<01:31, 17.5MB/s]
# Downloading data:   1%|▎                   | 21.4M/1.62G [00:02<01:23, 19.2MB/s]
# Downloading data:   2%|▎                   | 25.3M/1.62G [00:02<01:19, 20.1MB/s]
# Downloading data:   2%|▎                   | 29.2M/1.62G [00:02<01:16, 20.7MB/s]
# Downloading data:   2%|▍                   | 33.3M/1.62G [00:02<01:14, 21.4MB/s]
# Downloading data:   2%|▍                   | 37.3M/1.62G [00:02<01:12, 21.8MB/s]
# Downloading data:   3%|▌                   | 41.2M/1.62G [00:02<01:11, 21.9MB/s]
# Downloading data:   3%|▌                   | 45.3M/1.62G [00:03<01:10, 22.3MB/s]
# Downloading data:   3%|▌                   | 48.7M/1.62G [00:03<01:13, 21.4MB/s]
# Downloading data:   3%|▋                   | 52.8M/1.62G [00:03<01:11, 21.8MB/s]
# Downloading data:   4%|▋                   | 56.7M/1.62G [00:03<01:11, 21.9MB/s]
# Downloading data:   4%|▊                   | 60.8M/1.62G [00:03<01:09, 22.3MB/s]
# Downloading data:   4%|▊                   | 64.9M/1.62G [00:04<01:08, 22.5MB/s]
# Downloading data:   4%|▊                   | 68.8M/1.62G [00:04<01:09, 22.4MB/s]
# Downloading data:   5%|▉                   | 72.8M/1.62G [00:04<01:08, 22.6MB/s]
# Downloading data:   5%|▉                   | 76.7M/1.62G [00:04<01:08, 22.4MB/s]
# Downloading data:   5%|▉                   | 80.7M/1.62G [00:04<01:09, 22.3MB/s]
# Downloading data:   5%|█                   | 84.7M/1.62G [00:04<01:08, 22.4MB/s]
# Downloading data:   5%|█                   | 88.7M/1.62G [00:05<01:07, 22.6MB/s]
# Downloading data:   6%|█▏                  | 92.8M/1.62G [00:05<01:07, 22.7MB/s]
# Downloading data:   6%|█▏                  | 96.9M/1.62G [00:05<01:06, 22.8MB/s]
# Downloading data:   6%|█▎                   | 101M/1.62G [00:05<01:07, 22.6MB/s]
# Downloading data:   6%|█▎                   | 105M/1.62G [00:05<01:07, 22.5MB/s]
# Downloading data:   7%|█▍                   | 109M/1.62G [00:05<01:06, 22.6MB/s]
# Downloading data:   7%|█▍                   | 113M/1.62G [00:06<01:06, 22.7MB/s]
# Downloading data:   7%|█▌                   | 117M/1.62G [00:06<01:05, 22.8MB/s]
# Downloading data:   7%|█▌                   | 121M/1.62G [00:06<01:05, 22.8MB/s]
# Downloading data:   8%|█▌                   | 125M/1.62G [00:06<01:05, 22.8MB/s]
# Downloading data:   8%|█▋                   | 129M/1.62G [00:06<01:05, 22.7MB/s]
# Downloading data:   8%|█▋                   | 133M/1.62G [00:07<01:06, 22.5MB/s]
# Downloading data:   8%|█▊                   | 137M/1.62G [00:07<01:06, 22.4MB/s]
# Downloading data:   9%|█▊                   | 141M/1.62G [00:07<01:05, 22.6MB/s]
# Downloading data:   9%|█▉                   | 145M/1.62G [00:07<01:05, 22.6MB/s]
# Downloading data:   9%|█▉                   | 149M/1.62G [00:07<01:05, 22.5MB/s]
# Downloading data:   9%|█▉                   | 153M/1.62G [00:07<01:04, 22.7MB/s]
# Downloading data:  10%|██                   | 157M/1.62G [00:08<01:04, 22.6MB/s]
# Downloading data:  10%|██                   | 161M/1.62G [00:08<01:04, 22.7MB/s]
# Downloading data:  10%|██▏                  | 165M/1.62G [00:08<01:04, 22.6MB/s]
# Downloading data:  10%|██▏                  | 169M/1.62G [00:08<01:03, 22.7MB/s]
# Downloading data:  11%|██▏                  | 173M/1.62G [00:08<01:03, 22.6MB/s]
# Downloading data:  11%|██▎                  | 177M/1.62G [00:09<01:03, 22.6MB/s]
# Downloading data:  11%|██▎                  | 181M/1.62G [00:09<01:03, 22.7MB/s]
# Downloading data:  11%|██▍                  | 184M/1.62G [00:09<01:05, 21.8MB/s]
# Downloading data:  12%|██▍                  | 188M/1.62G [00:09<01:04, 22.1MB/s]
# Downloading data:  12%|██▍                  | 192M/1.62G [00:09<01:04, 22.2MB/s]
# Downloading data:  12%|██▌                  | 196M/1.62G [00:09<01:03, 22.3MB/s]
# Downloading data:  12%|██▌                  | 201M/1.62G [00:10<01:03, 22.5MB/s]
# Downloading data:  13%|██▋                  | 205M/1.62G [00:10<01:02, 22.6MB/s]
# Downloading data:  13%|██▋                  | 209M/1.62G [00:10<01:02, 22.5MB/s]
# Downloading data:  13%|██▊                  | 213M/1.62G [00:10<01:02, 22.6MB/s]
# Downloading data:  13%|██▊                  | 217M/1.62G [00:10<01:01, 22.7MB/s]
# Downloading data:  14%|██▊                  | 221M/1.62G [00:10<01:01, 22.6MB/s]
# Downloading data:  14%|██▉                  | 225M/1.62G [00:11<01:02, 22.5MB/s]
# Downloading data:  14%|██▉                  | 229M/1.62G [00:11<01:01, 22.5MB/s]
# Downloading data:  14%|███                  | 232M/1.62G [00:11<01:01, 22.4MB/s]
# Downloading data:  15%|███                  | 237M/1.62G [00:11<01:01, 22.3MB/s]
# Downloading data:  15%|███                  | 241M/1.62G [00:11<01:00, 22.7MB/s]
# Downloading data:  15%|███▏                 | 245M/1.62G [00:12<01:00, 22.6MB/s]
# Downloading data:  15%|███▏                 | 249M/1.62G [00:12<01:00, 22.7MB/s]
# Downloading data:  16%|███▎                 | 253M/1.62G [00:12<01:00, 22.7MB/s]
# Downloading data:  16%|███▎                 | 257M/1.62G [00:12<01:00, 22.5MB/s]
# Downloading data:  16%|███▍                 | 261M/1.62G [00:12<01:00, 22.4MB/s]
# Downloading data:  16%|███▍                 | 264M/1.62G [00:12<01:00, 22.4MB/s]
# Downloading data:  17%|███▍                 | 268M/1.62G [00:13<01:00, 22.3MB/s]
# Downloading data:  17%|███▌                 | 272M/1.62G [00:13<01:00, 22.3MB/s]
# Downloading data:  17%|███▌                 | 276M/1.62G [00:13<00:59, 22.4MB/s]
# Downloading data:  17%|███▋                 | 280M/1.62G [00:13<00:59, 22.4MB/s]
# Downloading data:  18%|███▋                 | 284M/1.62G [00:13<00:59, 22.6MB/s]
# Downloading data:  18%|███▋                 | 288M/1.62G [00:13<00:58, 22.6MB/s]
# Downloading data:  53%|███████████▏         | 858M/1.62G [00:39<00:33, 22.4MB/s]
# Downloading data:  53%|███████████▏         | 862M/1.62G [00:39<00:33, 22.3MB/s]
# Downloading data:  53%|███████████▏         | 866M/1.62G [00:39<00:33, 22.5MB/s]
# Downloading data:  54%|███████████▎         | 870M/1.62G [00:39<00:32, 22.7MB/s]
# Downloading data:  54%|███████████▎         | 874M/1.62G [00:40<00:32, 22.9MB/s]
# Downloading data:  54%|███████████▍         | 878M/1.62G [00:40<00:32, 22.7MB/s]
# Downloading data:  54%|███████████▍         | 882M/1.62G [00:40<00:32, 22.5MB/s]
# Downloading data:  55%|███████████▍         | 886M/1.62G [00:40<00:32, 22.6MB/s]
# Downloading data:  55%|███████████▌         | 890M/1.62G [00:40<00:32, 22.5MB/s]
# Downloading data:  55%|███████████▌         | 894M/1.62G [00:40<00:32, 22.5MB/s]
# Downloading data:  55%|███████████▋         | 898M/1.62G [00:41<00:32, 22.5MB/s]
# Downloading data:  56%|███████████▋         | 902M/1.62G [00:41<00:31, 22.5MB/s]
# Downloading data:  56%|███████████▊         | 906M/1.62G [00:41<00:32, 22.3MB/s]
# Downloading data:  56%|███████████▊         | 909M/1.62G [00:41<00:31, 22.3MB/s]
# Downloading data:  56%|███████████▊         | 913M/1.62G [00:41<00:31, 22.3MB/s]
# Downloading data:  57%|███████████▉         | 917M/1.62G [00:41<00:31, 22.4MB/s]
# Downloading data:  57%|███████████▉         | 921M/1.62G [00:42<00:30, 22.5MB/s]
# Downloading data:  57%|████████████         | 925M/1.62G [00:42<00:30, 22.3MB/s]
# Downloading data:  57%|████████████         | 929M/1.62G [00:42<00:30, 22.4MB/s]
# Downloading data:  58%|████████████         | 933M/1.62G [00:42<00:30, 22.5MB/s]
# Downloading data:  58%|████████████▏        | 937M/1.62G [00:42<00:30, 22.4MB/s]
# Downloading data:  58%|████████████▏        | 941M/1.62G [00:43<00:30, 22.5MB/s]
# Downloading data:  58%|████████████▎        | 945M/1.62G [00:43<00:30, 22.4MB/s]
# Downloading data:  59%|████████████▎        | 949M/1.62G [00:43<00:29, 22.5MB/s]
# Downloading data:  59%|████████████▎        | 953M/1.62G [00:43<00:29, 22.7MB/s]
# Downloading data:  59%|████████████▍        | 957M/1.62G [00:43<00:29, 22.6MB/s]
# Downloading data:  59%|████████████▍        | 961M/1.62G [00:43<00:29, 22.5MB/s]
# Downloading data:  60%|████████████▌        | 965M/1.62G [00:44<00:28, 22.7MB/s]
# Downloading data:  60%|████████████▌        | 969M/1.62G [00:44<00:28, 22.5MB/s]
# Downloading data:  60%|████████████▋        | 973M/1.62G [00:44<00:28, 22.6MB/s]
# Downloading data:  60%|████████████▋        | 977M/1.62G [00:44<00:28, 22.6MB/s]
# Downloading data:  61%|████████████▋        | 981M/1.62G [00:44<00:28, 22.6MB/s]
# Downloading data:  61%|████████████▊        | 985M/1.62G [00:44<00:27, 22.6MB/s]
# Downloading data:  61%|████████████▊        | 989M/1.62G [00:45<00:27, 22.8MB/s]
# Downloading data:  61%|████████████▉        | 993M/1.62G [00:45<00:27, 22.8MB/s]
# Downloading data:  62%|████████████▉        | 997M/1.62G [00:45<00:27, 22.7MB/s]
# Downloading data:  62%|████████████▍       | 1.00G/1.62G [00:45<00:27, 22.5MB/s]
# Downloading data:  62%|████████████▍       | 1.01G/1.62G [00:45<00:27, 22.0MB/s]
# Downloading data:  62%|████████████▍       | 1.01G/1.62G [00:46<00:27, 22.2MB/s]
# Downloading data:  63%|████████████▌       | 1.01G/1.62G [00:46<00:27, 22.2MB/s]
# Downloading data:  63%|████████████▌       | 1.02G/1.62G [00:46<00:26, 22.4MB/s]
# Downloading data:  63%|████████████▌       | 1.02G/1.62G [00:46<00:26, 22.4MB/s]
# Downloading data:  63%|████████████▋       | 1.02G/1.62G [00:46<00:26, 22.4MB/s]
# Downloading data:  64%|████████████▋       | 1.03G/1.62G [00:46<00:26, 22.5MB/s]
# Downloading data:  64%|████████████▊       | 1.03G/1.62G [00:47<00:25, 22.6MB/s]
# Downloading data:  64%|████████████▊       | 1.04G/1.62G [00:47<00:25, 22.5MB/s]
# Downloading data:  64%|████████████▊       | 1.04G/1.62G [00:47<00:25, 22.3MB/s]
# Downloading data:  65%|████████████▉       | 1.04G/1.62G [00:47<00:25, 22.4MB/s]
# Downloading data:  65%|████████████▉       | 1.05G/1.62G [00:47<00:25, 22.3MB/s]
# Downloading data:  65%|█████████████       | 1.05G/1.62G [00:47<00:25, 22.2MB/s]
# Downloading data:  65%|█████████████       | 1.06G/1.62G [00:48<00:25, 22.2MB/s]
# Downloading data:  66%|█████████████       | 1.06G/1.62G [00:48<00:25, 22.2MB/s]
# Downloading data:  66%|█████████████▏      | 1.06G/1.62G [00:48<00:24, 22.3MB/s]
# Downloading data:  66%|█████████████▏      | 1.07G/1.62G [00:48<00:24, 22.2MB/s]
# Downloading data:  66%|█████████████▎      | 1.07G/1.62G [00:48<00:24, 22.4MB/s]
# Downloading data:  67%|█████████████▎      | 1.08G/1.62G [00:49<00:24, 22.5MB/s]
# Downloading data:  67%|█████████████▎      | 1.08G/1.62G [00:49<00:23, 22.6MB/s]
# Downloading data:  67%|█████████████▍      | 1.08G/1.62G [00:49<00:23, 22.6MB/s]
# Downloading data:  67%|█████████████▍      | 1.09G/1.62G [00:49<00:23, 22.6MB/s]
# Downloading data:  68%|█████████████▌      | 1.09G/1.62G [00:49<00:23, 22.7MB/s]
# Downloading data:  68%|█████████████▌      | 1.10G/1.62G [00:49<00:22, 22.7MB/s]
# Downloading data:  68%|█████████████▌      | 1.10G/1.62G [00:50<00:22, 22.7MB/s]
# Downloading data:  68%|█████████████▋      | 1.10G/1.62G [00:50<00:22, 22.8MB/s]
# Downloading data:  69%|█████████████▋      | 1.11G/1.62G [00:50<00:22, 22.6MB/s]
# Downloading data:  69%|█████████████▊      | 1.11G/1.62G [00:50<00:22, 22.6MB/s]
# Downloading data:  69%|█████████████▊      | 1.12G/1.62G [00:50<00:23, 21.8MB/s]
# Downloading data:  69%|█████████████▊      | 1.12G/1.62G [00:51<00:22, 22.1MB/s]
# Downloading data:   0%|                    | 1.34M/1.57G [00:01<12:50, 2.04MB/s]
# Downloading data:   0%|                    | 2.70M/1.57G [00:01<06:40, 3.92MB/s]
# Downloading data:   0%|                    | 5.42M/1.57G [00:01<03:26, 7.60MB/s]
# Downloading data:   1%|                    | 9.53M/1.57G [00:01<02:04, 12.5MB/s]
# Downloading data:   1%|▏                   | 13.5M/1.57G [00:01<01:40, 15.6MB/s]
# Downloading data:   1%|▏                   | 17.5M/1.57G [00:01<01:27, 17.7MB/s]
# Downloading data:   1%|▎                   | 21.4M/1.57G [00:02<01:21, 19.1MB/s]
# Downloading data:   2%|▎                   | 25.5M/1.57G [00:02<01:16, 20.2MB/s]
# Downloading data:   2%|▍                   | 29.5M/1.57G [00:02<01:13, 21.0MB/s]
# Downloading data:   2%|▍                   | 33.5M/1.57G [00:02<01:11, 21.4MB/s]
# Downloading data:   2%|▍                   | 37.4M/1.57G [00:02<01:10, 21.7MB/s]
# Downloading data:   3%|▌                   | 41.5M/1.57G [00:02<01:09, 22.0MB/s]
# Downloading data:   3%|▌                   | 45.6M/1.57G [00:03<01:08, 22.3MB/s]
# Downloading data:   3%|▋                   | 49.5M/1.57G [00:03<01:08, 22.2MB/s]
# Downloading data:   3%|▋                   | 53.5M/1.57G [00:03<01:07, 22.4MB/s]
# Downloading data:   4%|▋                   | 57.5M/1.57G [00:03<01:07, 22.3MB/s]
# Downloading data:   4%|▊                   | 60.5M/1.57G [00:03<01:13, 20.7MB/s]
# Downloading data:   4%|▊                   | 64.5M/1.57G [00:04<01:10, 21.4MB/s]
# Downloading data:   4%|▊                   | 68.6M/1.57G [00:04<01:08, 21.8MB/s]
# Downloading data:   5%|▉                   | 72.6M/1.57G [00:04<01:07, 22.1MB/s]
# Downloading data:   5%|▉                   | 76.6M/1.57G [00:04<01:07, 22.0MB/s]
# Downloading data:   5%|█                   | 80.5M/1.57G [00:04<01:07, 22.1MB/s]
# Downloading data:   5%|█                   | 84.5M/1.57G [00:04<01:06, 22.3MB/s]
# Downloading data:   6%|█▏                  | 88.5M/1.57G [00:05<01:06, 22.3MB/s]
# Downloading data:   6%|█▏                  | 92.4M/1.57G [00:05<01:06, 22.2MB/s]
# Downloading data:   6%|█▏                  | 95.8M/1.57G [00:05<01:09, 21.3MB/s]
# Downloading data:   6%|█▎                  | 99.8M/1.57G [00:05<01:08, 21.6MB/s]
# Downloading data:   7%|█▍                   | 104M/1.57G [00:05<01:07, 21.9MB/s]
# Downloading data:   7%|█▍                   | 108M/1.57G [00:06<01:06, 21.9MB/s]
# Downloading data:   7%|█▍                   | 112M/1.57G [00:06<01:06, 22.0MB/s]
# Downloading data:   7%|█▌                   | 116M/1.57G [00:06<01:05, 22.3MB/s]
# Downloading data:   8%|█▌                   | 120M/1.57G [00:06<01:05, 22.1MB/s]
# Downloading data:   8%|█▋                   | 124M/1.57G [00:06<01:04, 22.4MB/s]
# Downloading data:   8%|█▋                   | 128M/1.57G [00:06<01:04, 22.5MB/s]
# Downloading data:   8%|█▊                   | 132M/1.57G [00:07<01:04, 22.3MB/s]
# Downloading data:   9%|█▊                   | 136M/1.57G [00:07<01:04, 22.3MB/s]
# Downloading data:   9%|█▊                   | 140M/1.57G [00:07<01:04, 22.3MB/s]
# Downloading data:   9%|█▉                   | 144M/1.57G [00:07<01:04, 22.3MB/s]
# Downloading data:   9%|█▉                   | 148M/1.57G [00:07<01:03, 22.3MB/s]
# Downloading data:  10%|██                   | 152M/1.57G [00:07<01:03, 22.4MB/s]
# Downloading data:  10%|██                   | 156M/1.57G [00:08<01:02, 22.5MB/s]
# Downloading data:  10%|██▏                  | 160M/1.57G [00:08<01:03, 22.4MB/s]
# Downloading data:  10%|██▏                  | 164M/1.57G [00:08<01:02, 22.4MB/s]
# Downloading data:  11%|██▏                  | 168M/1.57G [00:08<01:02, 22.6MB/s]
# Downloading data:  11%|██▎                  | 172M/1.57G [00:08<01:02, 22.4MB/s]
# Downloading data:  11%|██▎                  | 176M/1.57G [00:09<01:02, 22.4MB/s]
# Downloading data:  11%|██▍                  | 179M/1.57G [00:09<01:02, 22.3MB/s]
# Downloading data:  12%|██▍                  | 184M/1.57G [00:09<01:01, 22.6MB/s]
# Downloading data:  12%|██▌                  | 187M/1.57G [00:09<01:01, 22.4MB/s]
# Downloading data:  12%|██▌                  | 191M/1.57G [00:09<01:01, 22.4MB/s]
# Downloading data:  12%|██▌                  | 195M/1.57G [00:09<01:01, 22.5MB/s]
# Downloading data:  13%|██▋                  | 199M/1.57G [00:10<01:01, 22.4MB/s]
# Downloading data:  13%|██▋                  | 203M/1.57G [00:10<01:01, 22.4MB/s]
# Downloading data:  13%|██▊                  | 207M/1.57G [00:10<01:01, 22.3MB/s]
# Downloading data:  13%|██▊                  | 211M/1.57G [00:10<01:01, 22.2MB/s]
# Downloading data:  14%|██▊                  | 215M/1.57G [00:10<01:01, 22.2MB/s]
# Downloading data:  14%|██▉                  | 219M/1.57G [00:11<01:00, 22.2MB/s]
# Downloading data:  14%|██▉                  | 223M/1.57G [00:11<01:00, 22.1MB/s]
# Downloading data:  14%|███                  | 227M/1.57G [00:11<01:00, 22.2MB/s]
# Downloading data:  15%|███                  | 231M/1.57G [00:11<01:00, 22.2MB/s]
# Downloading data:  15%|███▏                 | 235M/1.57G [00:11<01:00, 22.2MB/s]
# Downloading data:  15%|███▏                 | 239M/1.57G [00:11<01:00, 22.2MB/s]
# Downloading data:  15%|███▏                 | 243M/1.57G [00:12<00:59, 22.3MB/s]
# Downloading data:  16%|███▎                 | 247M/1.57G [00:12<00:58, 22.5MB/s]
# Downloading data:  16%|███▎                 | 251M/1.57G [00:12<00:58, 22.6MB/s]
# Downloading data:  16%|███▍                 | 255M/1.57G [00:12<00:57, 22.7MB/s]
# Downloading data:  16%|███▍                 | 259M/1.57G [00:12<00:58, 22.6MB/s]
# Downloading data:  17%|███▌                 | 263M/1.57G [00:12<00:58, 22.5MB/s]
# Downloading data:  17%|███▌                 | 267M/1.57G [00:13<00:57, 22.6MB/s]
# Downloading data:  17%|███▌                 | 271M/1.57G [00:13<00:57, 22.7MB/s]
# Downloading data:  18%|███▋                 | 276M/1.57G [00:13<00:57, 22.8MB/s]
# Downloading data:  36%|███████▍             | 561M/1.57G [00:26<00:45, 22.5MB/s]
# Downloading data:  36%|███████▌             | 565M/1.57G [00:26<00:44, 22.4MB/s]
# Downloading data:  36%|███████▌             | 569M/1.57G [00:26<00:44, 22.5MB/s]
# Downloading data:  36%|███████▋             | 572M/1.57G [00:26<00:46, 21.7MB/s]
# Downloading data:  37%|███████▋             | 576M/1.57G [00:27<00:45, 22.1MB/s]
# Downloading data:  37%|███████▊             | 580M/1.57G [00:27<00:44, 22.2MB/s]
# Downloading data:  37%|███████▊             | 585M/1.57G [00:27<00:44, 22.4MB/s]
# Downloading data:  37%|███████▊             | 589M/1.57G [00:27<00:43, 22.5MB/s]
# Downloading data:  38%|███████▉             | 593M/1.57G [00:27<00:43, 22.6MB/s]
# Downloading data:  38%|███████▉             | 597M/1.57G [00:27<00:43, 22.6MB/s]
# Downloading data:  38%|████████             | 601M/1.57G [00:28<00:43, 22.5MB/s]
# Downloading data:  38%|████████             | 605M/1.57G [00:28<00:42, 22.6MB/s]
# Downloading data:  39%|████████▏            | 609M/1.57G [00:28<00:42, 22.7MB/s]
# Downloading data:  39%|████████▏            | 613M/1.57G [00:28<00:42, 22.6MB/s]
# Downloading data:  39%|████████▏            | 617M/1.57G [00:28<00:42, 22.6MB/s]
# ...
# Downloading data:  77%|███████████████▍    | 1.26G/1.64G [01:09<00:23, 16.3MB/s]
# Downloading data:  77%|███████████████▍    | 1.27G/1.64G [01:09<00:22, 16.8MB/s]
# Downloading data:  77%|███████████████▍    | 1.27G/1.64G [01:09<00:21, 17.2MB/s]
# Downloading data:  78%|███████████████▌    | 1.27G/1.64G [01:09<00:20, 17.5MB/s]
# Downloading data:  78%|███████████████▌    | 1.28G/1.64G [01:09<00:20, 17.8MB/s]
# Downloading data:  78%|███████████████▌    | 1.28G/1.64G [01:09<00:19, 18.1MB/s]
# Downloading data:  78%|███████████████▋    | 1.28G/1.64G [01:10<00:19, 18.5MB/s]
# Downloading data:  78%|███████████████▋    | 1.29G/1.64G [01:10<00:18, 18.7MB/s]
# Downloading data:  79%|███████████████▋    | 1.29G/1.64G [01:10<00:18, 18.8MB/s]
# Downloading data:  79%|███████████████▊    | 1.29G/1.64G [01:10<00:18, 19.0MB/s]
# Downloading data:  79%|███████████████▊    | 1.30G/1.64G [01:10<00:17, 19.2MB/s]
# Downloading data:  79%|███████████████▊    | 1.30G/1.64G [01:11<00:17, 19.4MB/s]
# Downloading data:  80%|███████████████▉    | 1.30G/1.64G [01:11<00:17, 19.7MB/s]
# Downloading data:  80%|███████████████▉    | 1.31G/1.64G [01:11<00:16, 19.9MB/s]
# Downloading data:  80%|███████████████▉    | 1.31G/1.64G [01:11<00:16, 20.3MB/s]
# Downloading data:  80%|████████████████    | 1.32G/1.64G [01:11<00:15, 20.5MB/s]
# Downloading data:  80%|████████████████    | 1.32G/1.64G [01:11<00:15, 20.7MB/s]
# Downloading data:  81%|████████████████▏   | 1.32G/1.64G [01:12<00:15, 20.8MB/s]
# Downloading data:  81%|████████████████▏   | 1.33G/1.64G [01:12<00:14, 21.0MB/s]
# Downloading data:  81%|████████████████▏   | 1.33G/1.64G [01:12<00:14, 21.4MB/s]
# Downloading data:  81%|████████████████▎   | 1.33G/1.64G [01:12<00:14, 21.3MB/s]
# Downloading data:  82%|████████████████▎   | 1.34G/1.64G [01:12<00:13, 21.6MB/s]
# Downloading data:  82%|████████████████▎   | 1.34G/1.64G [01:13<00:13, 22.0MB/s]
# Downloading data:  82%|████████████████▍   | 1.35G/1.64G [01:13<00:13, 22.1MB/s]
# Downloading data:  82%|████████████████▍   | 1.35G/1.64G [01:13<00:13, 22.1MB/s]
# Downloading data:  83%|████████████████▌   | 1.35G/1.64G [01:13<00:13, 21.9MB/s]
# Downloading data:  83%|████████████████▌   | 1.36G/1.64G [01:13<00:12, 22.0MB/s]
# Downloading data:  83%|████████████████▌   | 1.36G/1.64G [01:13<00:12, 22.0MB/s]
# Downloading data:  83%|████████████████▋   | 1.37G/1.64G [01:14<00:13, 20.8MB/s]
# Downloading data:  84%|████████████████▋   | 1.37G/1.64G [01:14<00:12, 21.3MB/s]
# Downloading data:  84%|████████████████▋   | 1.37G/1.64G [01:14<00:12, 21.5MB/s]
# Downloading data:  84%|████████████████▊   | 1.38G/1.64G [01:14<00:12, 21.7MB/s]
# Downloading data:  84%|████████████████▊   | 1.38G/1.64G [01:14<00:11, 21.9MB/s]
# Downloading data:  84%|████████████████▉   | 1.39G/1.64G [01:14<00:11, 22.1MB/s]
# Downloading data:  85%|████████████████▉   | 1.39G/1.64G [01:15<00:11, 22.0MB/s]
# Downloading data:  85%|████████████████▉   | 1.39G/1.64G [01:15<00:12, 20.1MB/s]
# Downloading data:  85%|█████████████████   | 1.40G/1.64G [01:15<00:11, 20.6MB/s]
# Downloading data:  85%|█████████████████   | 1.40G/1.64G [01:15<00:11, 21.1MB/s]
# Downloading data:  86%|█████████████████   | 1.40G/1.64G [01:15<00:11, 20.3MB/s]
# Downloading data:  86%|█████████████████▏  | 1.41G/1.64G [01:16<00:11, 20.7MB/s]
# Downloading data:  86%|█████████████████▏  | 1.41G/1.64G [01:16<00:11, 20.6MB/s]
# Downloading data:  86%|█████████████████▎  | 1.41G/1.64G [01:16<00:10, 21.0MB/s]
# Downloading data:  86%|█████████████████▎  | 1.42G/1.64G [01:16<00:10, 21.5MB/s]
# Downloading data:  87%|█████████████████▎  | 1.42G/1.64G [01:16<00:09, 22.1MB/s]
# Downloading data:  87%|█████████████████▍  | 1.43G/1.64G [01:16<00:09, 22.2MB/s]
# Downloading data:  87%|█████████████████▍  | 1.43G/1.64G [01:17<00:09, 22.3MB/s]
# Downloading data:  87%|█████████████████▍  | 1.43G/1.64G [01:17<00:09, 22.4MB/s]
# Downloading data:  88%|█████████████████▌  | 1.44G/1.64G [01:17<00:09, 22.3MB/s]
# Downloading data:  88%|█████████████████▌  | 1.44G/1.64G [01:17<00:08, 22.3MB/s]
# Downloading data:  88%|█████████████████▋  | 1.45G/1.64G [01:17<00:08, 22.4MB/s]
# Downloading data:  88%|█████████████████▋  | 1.45G/1.64G [01:17<00:08, 22.4MB/s]
# Downloading data:  89%|█████████████████▋  | 1.45G/1.64G [01:18<00:08, 22.3MB/s]
# Downloading data:  89%|█████████████████▊  | 1.46G/1.64G [01:18<00:08, 22.1MB/s]
# Downloading data:  89%|█████████████████▊  | 1.46G/1.64G [01:18<00:07, 22.2MB/s]
# Downloading data:  89%|█████████████████▊  | 1.47G/1.64G [01:18<00:08, 20.4MB/s]
# Downloading data:  90%|█████████████████▉  | 1.47G/1.64G [01:18<00:08, 19.8MB/s]
# Downloading data:  90%|█████████████████▉  | 1.47G/1.64G [01:19<00:08, 19.0MB/s]
# Downloading data:  90%|█████████████████▉  | 1.47G/1.64G [01:19<00:09, 18.3MB/s]
# Downloading data:  90%|██████████████████  | 1.48G/1.64G [01:19<00:09, 18.0MB/s]
# Downloading data:  90%|██████████████████  | 1.48G/1.64G [01:19<00:08, 17.8MB/s]
# Downloading data:  90%|██████████████████  | 1.48G/1.64G [01:19<00:08, 17.8MB/s]
# Downloading data:  91%|██████████████████▏ | 1.49G/1.64G [01:19<00:08, 17.8MB/s]
# Downloading data:  91%|██████████████████▏ | 1.49G/1.64G [01:20<00:08, 17.8MB/s]
# Downloading data:  91%|██████████████████▏ | 1.49G/1.64G [01:20<00:08, 17.9MB/s]
# Downloading data:  91%|██████████████████▏ | 1.50G/1.64G [01:20<00:07, 18.1MB/s]
# Downloading data:  91%|██████████████████▎ | 1.50G/1.64G [01:20<00:07, 18.2MB/s]
# Downloading data:  92%|██████████████████▎ | 1.50G/1.64G [01:20<00:07, 18.3MB/s]
# Downloading data:  92%|██████████████████▎ | 1.51G/1.64G [01:20<00:07, 18.4MB/s]
# Downloading data:  92%|██████████████████▍ | 1.51G/1.64G [01:21<00:07, 18.5MB/s]
# Downloading data:  92%|██████████████████▍ | 1.51G/1.64G [01:21<00:06, 18.5MB/s]
# Downloading data:  92%|██████████████████▍ | 1.52G/1.64G [01:21<00:06, 18.7MB/s]
# Downloading data:  93%|██████████████████▌ | 1.52G/1.64G [01:21<00:06, 18.7MB/s]
# Downloading data:  93%|██████████████████▌ | 1.52G/1.64G [01:21<00:06, 18.9MB/s]
# Downloading data:  93%|██████████████████▌ | 1.53G/1.64G [01:22<00:06, 19.0MB/s]
# Downloading data:  93%|██████████████████▋ | 1.53G/1.64G [01:22<00:05, 19.1MB/s]
# Downloading data:  93%|██████████████████▋ | 1.53G/1.64G [01:22<00:05, 20.9MB/s]
# Downloading data:  94%|██████████████████▋ | 1.54G/1.64G [01:22<00:04, 21.8MB/s]
# Downloading data:  94%|██████████████████▊ | 1.54G/1.64G [01:22<00:05, 19.0MB/s]
# Downloading data:  94%|██████████████████▊ | 1.54G/1.64G [01:22<00:05, 17.9MB/s]
# Downloading data:  94%|██████████████████▊ | 1.54G/1.64G [01:22<00:05, 18.5MB/s]
# Downloading data:  94%|██████████████████▊ | 1.55G/1.64G [01:23<00:04, 20.5MB/s]
# Downloading data:  94%|██████████████████▉ | 1.55G/1.64G [01:23<00:04, 20.5MB/s]
# Downloading data:  95%|██████████████████▉ | 1.55G/1.64G [01:23<00:05, 17.8MB/s]
# Downloading data:  95%|██████████████████▉ | 1.55G/1.64G [01:23<00:04, 18.6MB/s]
# Downloading data:  95%|██████████████████▉ | 1.56G/1.64G [01:23<00:03, 21.2MB/s]
# Downloading data:  95%|███████████████████ | 1.56G/1.64G [01:23<00:03, 20.5MB/s]
# Downloading data:  95%|███████████████████ | 1.56G/1.64G [01:23<00:04, 17.8MB/s]
# Downloading data:  95%|███████████████████ | 1.56G/1.64G [01:23<00:04, 19.0MB/s]
# Downloading data:  96%|███████████████████ | 1.57G/1.64G [01:24<00:03, 19.3MB/s]
# Downloading data:  96%|███████████████████▏| 1.57G/1.64G [01:24<00:03, 19.4MB/s]
# Downloading data:  96%|███████████████████▏| 1.57G/1.64G [01:24<00:03, 19.8MB/s]
# Downloading data:  96%|███████████████████▏| 1.58G/1.64G [01:24<00:02, 21.5MB/s]
# Downloading data:  96%|███████████████████▎| 1.58G/1.64G [01:24<00:02, 20.3MB/s]
# Downloading data:  96%|███████████████████▎| 1.58G/1.64G [01:24<00:03, 17.8MB/s]
# Downloading data:  97%|███████████████████▎| 1.58G/1.64G [01:25<00:02, 19.5MB/s]
# Downloading data:  97%|███████████████████▎| 1.59G/1.64G [01:25<00:02, 19.6MB/s]
# Downloading data:  97%|███████████████████▍| 1.59G/1.64G [01:25<00:02, 19.9MB/s]
# Downloading data:  97%|███████████████████▍| 1.59G/1.64G [01:25<00:01, 22.8MB/s]
# Downloading data:  97%|███████████████████▍| 1.60G/1.64G [01:25<00:02, 19.8MB/s]
# Downloading data:  98%|███████████████████▌| 1.60G/1.64G [01:25<00:02, 17.6MB/s]
# Downloading data:  98%|███████████████████▌| 1.60G/1.64G [01:25<00:01, 20.0MB/s]
# Downloading data:  98%|███████████████████▌| 1.61G/1.64G [01:25<00:01, 23.6MB/s]
# Downloading data:  98%|███████████████████▌| 1.61G/1.64G [01:26<00:01, 20.5MB/s]
# Downloading data:  98%|███████████████████▋| 1.61G/1.64G [01:26<00:01, 18.2MB/s]
# Downloading data:  98%|███████████████████▋| 1.61G/1.64G [01:26<00:01, 18.9MB/s]
# Downloading data:  99%|███████████████████▋| 1.62G/1.64G [01:26<00:01, 20.2MB/s]
# Downloading data:  99%|███████████████████▋| 1.62G/1.64G [01:26<00:01, 20.9MB/s]
# Downloading data:  99%|███████████████████▊| 1.62G/1.64G [01:26<00:01, 18.1MB/s]
# Downloading data:  99%|███████████████████▊| 1.62G/1.64G [01:26<00:00, 19.6MB/s]
# Downloading data:  99%|███████████████████▊| 1.63G/1.64G [01:27<00:00, 20.5MB/s]
# Downloading data:  99%|███████████████████▊| 1.63G/1.64G [01:27<00:00, 20.4MB/s]
# Downloading data:  99%|███████████████████▉| 1.63G/1.64G [01:27<00:00, 17.7MB/s]
# Downloading data: 100%|███████████████████▉| 1.63G/1.64G [01:27<00:00, 20.6MB/s]
# Downloading data: 100%|███████████████████▉| 1.64G/1.64G [01:27<00:00, 21.7MB/s]
# Downloading data: 100%|████████████████████| 1.64G/1.64G [01:27<00:00, 18.7MB/s]
#
# Downloading data:   0%|                              | 0.00/293M [00:00<?, ?B/s]
# Downloading data:   0%|                      | 19.5k/293M [00:00<43:25, 113kB/s]
# Downloading data:   0%|                      | 52.2k/293M [00:00<31:12, 157kB/s]
# Downloading data:   0%|                       | 139k/293M [00:00<15:39, 312kB/s]
# Downloading data:   0%|                       | 313k/293M [00:00<08:23, 582kB/s]
# Downloading data:   0%|                      | 662k/293M [00:00<04:28, 1.09MB/s]
# Downloading data:   0%|                     | 1.32M/293M [00:01<02:25, 2.00MB/s]
# Downloading data:   1%|▏                    | 2.69M/293M [00:01<01:14, 3.90MB/s]
# Downloading data:   2%|▍                    | 5.45M/293M [00:01<00:37, 7.66MB/s]
# Downloading data:   3%|▋                    | 9.54M/293M [00:01<00:22, 12.5MB/s]
# Downloading data:   5%|▉                    | 13.7M/293M [00:01<00:17, 15.8MB/s]
# Downloading data:   6%|█▎                   | 17.8M/293M [00:01<00:15, 18.1MB/s]
# Downloading data:   7%|█▌                   | 21.7M/293M [00:02<00:14, 19.3MB/s]
# Downloading data:   9%|█▊                   | 25.8M/293M [00:02<00:13, 20.3MB/s]
# Downloading data:  10%|██▏                  | 29.7M/293M [00:02<00:12, 21.0MB/s]
# Downloading data:  12%|██▍                  | 33.8M/293M [00:02<00:12, 21.5MB/s]
# Downloading data:  13%|██▋                  | 37.7M/293M [00:02<00:11, 21.7MB/s]
# Downloading data:  14%|██▉                  | 41.6M/293M [00:03<00:11, 21.8MB/s]
# Downloading data:  16%|███▎                 | 45.6M/293M [00:03<00:11, 21.8MB/s]
# Downloading data:  17%|███▌                 | 49.6M/293M [00:03<00:11, 22.0MB/s]
# Downloading data:  18%|███▊                 | 53.6M/293M [00:03<00:10, 22.3MB/s]
# Downloading data:  20%|████▏                | 57.6M/293M [00:03<00:10, 22.2MB/s]
# Downloading data:  21%|████▍                | 61.7M/293M [00:03<00:10, 22.5MB/s]
# Downloading data:  22%|████▋                | 65.7M/293M [00:04<00:10, 22.6MB/s]
# Downloading data:  24%|████▉                | 69.8M/293M [00:04<00:09, 22.6MB/s]
# Downloading data:  25%|█████▎               | 73.8M/293M [00:04<00:09, 22.7MB/s]
# Downloading data:  27%|█████▌               | 77.7M/293M [00:04<00:09, 22.5MB/s]
# Downloading data:  28%|█████▊               | 81.7M/293M [00:04<00:09, 22.5MB/s]
# Downloading data:  29%|██████▏              | 85.8M/293M [00:04<00:09, 22.6MB/s]
# Downloading data:  31%|██████▍              | 89.9M/293M [00:05<00:08, 22.8MB/s]
# Downloading data:  32%|██████▋              | 93.9M/293M [00:05<00:08, 22.6MB/s]
# Downloading data:  33%|███████              | 98.0M/293M [00:05<00:08, 22.7MB/s]
# Downloading data:  35%|███████▋              | 102M/293M [00:05<00:08, 22.8MB/s]
# Downloading data:  36%|███████▉              | 106M/293M [00:05<00:08, 22.9MB/s]
# Downloading data:  38%|████████▎             | 110M/293M [00:06<00:08, 22.7MB/s]
# Downloading data:  39%|████████▌             | 114M/293M [00:06<00:07, 22.7MB/s]
# Downloading data:  40%|████████▊             | 118M/293M [00:06<00:07, 22.7MB/s]
# Downloading data:  42%|█████████▏            | 122M/293M [00:06<00:07, 22.4MB/s]
# Downloading data:  43%|█████████▍            | 126M/293M [00:06<00:07, 22.5MB/s]
# Downloading data:  44%|█████████▊            | 130M/293M [00:06<00:07, 22.6MB/s]
# Downloading data:  46%|██████████            | 134M/293M [00:07<00:07, 22.6MB/s]
# Downloading data:  47%|██████████▎           | 138M/293M [00:07<00:06, 22.4MB/s]
# Downloading data:  48%|██████████▋           | 142M/293M [00:07<00:06, 22.4MB/s]
# Downloading data:  50%|██████████▉           | 146M/293M [00:07<00:06, 22.5MB/s]
# Downloading data:  51%|███████████▎          | 150M/293M [00:07<00:06, 22.3MB/s]
# Downloading data:  53%|███████████▌          | 154M/293M [00:07<00:06, 22.5MB/s]
# Downloading data:  54%|███████████▊          | 158M/293M [00:08<00:06, 22.3MB/s]
# Downloading data:  55%|████████████▏         | 162M/293M [00:08<00:05, 22.3MB/s]
# Downloading data:  57%|████████████▍         | 166M/293M [00:08<00:05, 22.6MB/s]
# Downloading data:  58%|████████████▊         | 170M/293M [00:08<00:05, 22.6MB/s]
# Downloading data:  59%|█████████████         | 174M/293M [00:08<00:05, 22.6MB/s]
# Downloading data:  61%|█████████████▎        | 178M/293M [00:09<00:05, 22.5MB/s]
# Downloading data:  62%|█████████████▋        | 182M/293M [00:09<00:04, 22.4MB/s]
# Downloading data:  63%|█████████████▉        | 186M/293M [00:09<00:04, 22.5MB/s]
# Downloading data:  65%|██████████████▎       | 190M/293M [00:09<00:04, 22.5MB/s]
# Downloading data:  66%|██████████████▌       | 194M/293M [00:09<00:04, 22.6MB/s]
# Downloading data:  68%|██████████████▊       | 198M/293M [00:09<00:04, 22.7MB/s]
# Downloading data:  69%|███████████████▏      | 202M/293M [00:10<00:04, 22.7MB/s]
# Downloading data:  70%|███████████████▍      | 206M/293M [00:10<00:03, 22.6MB/s]
# Downloading data:  72%|███████████████▊      | 210M/293M [00:10<00:03, 22.6MB/s]
# Downloading data:  73%|████████████████      | 214M/293M [00:10<00:03, 22.5MB/s]
# Downloading data:  74%|████████████████▎     | 218M/293M [00:10<00:03, 22.3MB/s]
# Downloading data:  76%|████████████████▋     | 222M/293M [00:11<00:03, 22.2MB/s]
# Downloading data:  77%|████████████████▉     | 226M/293M [00:11<00:03, 22.2MB/s]
# Downloading data:  78%|█████████████████▎    | 230M/293M [00:11<00:02, 22.3MB/s]
# Downloading data:  80%|█████████████████▌    | 234M/293M [00:11<00:02, 22.6MB/s]
# Downloading data:  81%|█████████████████▊    | 238M/293M [00:11<00:02, 22.6MB/s]
# Downloading data:  83%|██████████████████▏   | 242M/293M [00:11<00:02, 22.6MB/s]
# Downloading data:  84%|██████████████████▍   | 246M/293M [00:12<00:02, 22.4MB/s]
# Downloading data:  85%|██████████████████▊   | 250M/293M [00:12<00:01, 22.6MB/s]
# Downloading data:  87%|███████████████████   | 254M/293M [00:12<00:01, 22.4MB/s]
# Downloading data:  88%|███████████████████▎  | 258M/293M [00:12<00:01, 22.3MB/s]
# Downloading data:  89%|███████████████████▋  | 262M/293M [00:12<00:01, 22.5MB/s]
# Downloading data:  91%|███████████████████▉  | 266M/293M [00:12<00:01, 22.5MB/s]
# Downloading data:  92%|████████████████████▎ | 270M/293M [00:13<00:01, 22.4MB/s]
# Downloading data:  93%|████████████████████▌ | 274M/293M [00:13<00:00, 22.3MB/s]
# Downloading data:  95%|████████████████████▊ | 278M/293M [00:13<00:00, 22.4MB/s]
# Downloading data:  96%|█████████████████████▏| 282M/293M [00:13<00:00, 22.6MB/s]
# Downloading data:  98%|█████████████████████▍| 286M/293M [00:13<00:00, 22.5MB/s]
# Downloading data: 100%|██████████████████████| 293M/293M [00:14<00:00, 20.9MB/s]
# Downloading data files: 100%|████████████████████| 5/5 [14:10<00:00, 170.03s/it]
# Extracting data files:  60%|█████████████▏        | 3/5 [01:11<00:38, 19.42s/it]

# %% [markdown]
# We apply filtering/data-processing to the dataset. We've skipped explanations as to why we're filtering, as extensive information can be found [here](https://github.com/andrusenkoau/NeMo/blob/esperanto_example/docs/source/asr/examples/esperanto_asr/esperanto_asr.rst).

# %%
dev_manifest = f"{data_dir}/validation/validation_mozilla-foundation_common_voice_11_0_manifest.json"
test_manifest = f"{data_dir}/test/test_mozilla-foundation_common_voice_11_0_manifest.json"
train_manifest = f"{data_dir}/train/train_mozilla-foundation_common_voice_11_0_manifest.json"

def compute_char_counts(manifest):
    char_counts = {}
    with open(manifest, 'r') as fn_in:
        for line in tqdm(fn_in, desc="Compute counts.."):
            line = line.replace("\n", "")
            data = json.loads(line)
            text = data["text"]
            for word in text.split():
                for char in word:
                    if char not in char_counts:
                        char_counts[char] = 1
                    else:
                        char_counts[char] += 1
    return char_counts

char_counts = compute_char_counts(train_manifest)

threshold = 10
trash_char_list = []

for char in char_counts:
    if char_counts[char] <= threshold:
        trash_char_list.append(char)

def clear_data_set(manifest, char_rate_threshold=None):

    chars_to_ignore_regex = "[\.\,\?\:\-!;()«»…\]\[/\*–‽+&_\\½√>€™$•¼}{~—=“\"”″‟„]"
    addition_ignore_regex = f"[{''.join(trash_char_list)}]"

    manifest_clean = manifest + '.clean'
    war_count = 0
    with open(manifest, 'r') as fn_in, \
        open(manifest_clean, 'w', encoding='utf-8') as fn_out:
        for line in tqdm(fn_in, desc="Cleaning manifest data"):
            line = line.replace("\n", "")
            data = json.loads(line)
            text = data["text"]
            if char_rate_threshold and len(text.replace(' ', '')) / float(data['duration']) > char_rate_threshold:
                print(f"[WARNING]: {data['audio_filepath']} has char rate > 15 per sec: {len(text)} chars, {data['duration']} duration")
                war_count += 1
                continue
            text = re.sub(chars_to_ignore_regex, "", text)
            text = re.sub(addition_ignore_regex, "", text)
            data["text"] = text
            data = json.dumps(data, ensure_ascii=False)
            fn_out.write(f"{data}\n")
    print(f"[INFO]: {war_count} files were removed from manifest")

clear_data_set(dev_manifest)
clear_data_set(test_manifest)
clear_data_set(train_manifest, char_rate_threshold=15)

# %% [markdown]
# When the dataset is mounted to the SageMaker instance, the filepaths change. To handle this, we change the root path of the manifest entries to point to the correct mounted directory.

# %%
dev_manifest = dev_manifest + '.clean'


def replace_real_dir_with_mount_dir(manifest_path, data_root, mount_dir):
    with open(manifest_path) as f:
        entries = [json.loads(x) for x in f]
    for entry in entries:
        entry['audio_filepath'] = entry['audio_filepath'].replace(str(data_root), str(mount_dir))
    with open(manifest_path + '.mount', 'w') as f:
        f.write('\n'.join([json.dumps(x) for x in entries]))

replace_real_dir_with_mount_dir(dev_manifest, data_dir.absolute(), "/opt/ml/input/data/testing/")

# %% [markdown]
# To improve performance, we also tar the training dataset to improve throughput when reading/writing from S3 directly within the remote instance.

# %%
train_manifest = train_manifest + '.clean'

# %%
# !python ./code/convert_to_tarred_audio_dataset.py \
  --manifest_path={train_manifest} \
  --target_dir=./data/train_tarred_1bk \
  --num_shards=512 \
  --max_duration=15.0 \
  --min_duration=1.0 \
  --shuffle \
  --shuffle_seed=1 \
  --sort_in_shards \
  --workers=-1

# %% [markdown]
# Finally, we generate the tokenizer that we will be using for training using the training manifest. Further information about parameters when choosing vocab sizes can be found [here](https://github.com/andrusenkoau/NeMo/blob/esperanto_example/docs/source/asr/examples/esperanto_asr/esperanto_asr.rst).

# %%
vocab_size=128

# !python ./code/process_asr_text_tokenizer.py \
  --manifest={train_manifest} \
  --vocab_size={vocab_size} \
  --data_root=./data/tokenizers \
  --tokenizer="spe" \
  --spe_type=bpe \
  --no_lower_case

# %% [markdown]
# ### 5. Upload the Dataset to S3
#
# This can take some time depending on your upload speed. We are uploading roughly 111GB of data to S3.

# %%
# optional, move the raw training dataset out of the data folder to reduce data transfer
shutil.move(f"{dataset_dir}/train/", root_dir / "train_raw/")

prefix = "cv_esperanto"
bucket = sess.default_bucket()

loc = sess.upload_data(path=str(data_dir), bucket=bucket, key_prefix=prefix)
loc

# %% [markdown]
# ### 4. Configure the training job
#
# Now we configure the training job, by modifying the `config.yaml` file that is stored in our source code directory.
# We pass relative directory paths for the data based on the SageMaker mount directory on the remote instance.

# %%
# the output path for the model checkpoints/logs
output_path = "s3://" + sess.default_bucket() + "/nemo-output/"

# %% [markdown]
# We setup the training configuration based on the Esperanto experiments ran [here](https://github.com/andrusenkoau/NeMo/blob/esperanto_example/docs/source/asr/examples/esperanto_asr/esperanto_asr.rst).
#
# If you change the number of GPUs on the instance, remember to change the values below.

# %%
global_batch_size = 1024
train_batch_size = 8
n_gpus = 8
num_nodes = 1 # set this to the number of nodes you'd like to train on
accumulate_grad_batches = int(global_batch_size / (n_gpus * num_nodes * train_batch_size))

# %%
conf = OmegaConf.load(config_path)

# data config setup
conf.model.train_ds.batch_size=train_batch_size
conf.model.train_ds.is_tarred = True
conf.model.train_ds.tarred_audio_filepaths = "/opt/ml/input/data/training/train_tarred_1bk/audio__OP_0..511_CL_.tar"
conf.model.train_ds.manifest_filepath = "/opt/ml/input/data/training/train_tarred_1bk/tarred_audio_manifest.json"
conf.model.validation_ds.manifest_filepath = "/opt/ml/input/data/testing/validation/validation_mozilla-foundation_common_voice_11_0_manifest.json.clean.mount"

# optimization setup
conf.model.optim.lr = 1e-3
conf.model.optim.sched.name = "CosineAnnealing"

# remove variable which is not needed when using CosineAnnealing
conf.model.optim.sched.pop('d_model')

# logging/output setup
conf.exp_manager.exp_dir = "/opt/ml/model/"

# the BPE tokenizer location based on the remote instance mounted directory
conf.model.tokenizer.dir = "/opt/ml/input/data/training/tokenizers/tokenizer_spe_bpe_v128"

# the pre-trained model we want to fine-tune
conf.init_from_nemo_model = "ssl_en_conformer_large.nemo"

# training setup
conf.trainer.accelerator = "gpu"
# enable SageMaker DDP
conf.trainer.strategy = "smddp"
conf.trainer.max_epochs = 300
conf.trainer.accumulate_grad_batches = accumulate_grad_batches
conf.trainer.precision = 16 # if using Ampere or above (i.e ml.p4d.24xlarge), you can use bf16 (BFloat16) 

# resume flags if crashes occur
conf.exp_manager.resume_if_exists=True
conf.exp_manager.resume_ignore_no_checkpoint=True

# %% [markdown]
# Uncomment the below cell you want to use W&B, you'll need to pass your W&B token at a later step.

# %%
# conf.exp_manager.wandb_logger_kwargs.name = "common_voice_esperanto"
# conf.exp_manager.create_wandb_logger = True
# conf.exp_manager.wandb_logger_kwargs.resume=True

# %%
# save the updated config
OmegaConf.save(conf, config_dir / 'config.yaml')

# %% [markdown]
# Download the pre-trained SSL model from NGC. We'll upload this model with our code to SageMaker.

# %%
# !wget --content-disposition https://api.ngc.nvidia.com/v2/models/nvidia/nemo/ssl_en_conformer_large/versions/1.10.1/zip -O {code_dir}/ssl_en_conformer_large_1.10.1.zip
# !unzip {code_dir}/ssl_en_conformer_large_1.10.1.zip -d {code_dir}

# %% [markdown]
# ### 5. Run training on SageMaker
#
# Pass the path of the training and validation data on S3 + the output directory on S3 to the PyTorch estimator, and call fit with the appropriate bucket locations for the training and testing data.

# %%
channels = {"training": loc, "testing": loc}

role = get_execution_role()

output_path = "s3://" + sess.default_bucket() + "/nemo-output/"

local_mode = False

if local_mode:
    instance_type = "local_gpu"
else:
    instance_type = "ml.p3.16xlarge"
    
instance_count = num_nodes

est = PyTorch(
    entry_point="speech_to_text_ctc_bpe.py",
    source_dir="code",  # directory of your training script
    role=role,
    instance_type=instance_type,
    instance_count=instance_count,
    framework_version="1.12.0",
    py_version="py38",
    volume_size=125,
    output_path=output_path,
    hyperparameters={'config-path': 'conf', 'config-name': 'config'},
    # uncomment if you're enabling WANDB, and pass your own API key.
    # environment={"WANDB_API_KEY": "<WANDB_API_KEY>"},
    # enable SageMaker Optimized DDP for multi-node scaling
    distribution={"smdistributed":{"dataparallel":{"enabled":True, "fp16": True}}},
    input_mode='FastFile' # enables reading from S3 directly, no need to download the data
)

est.fit(inputs=channels)

# %% [markdown]
# ### 6. Download model, (Optional) Tensorboard Logs
#
# SageMaker stores our models/logs within a tar file after training has finished. These can be obtained from S3 like below.
#
# We also visualize the training logs. We suggest using an external logger (such as W&B) to track training progress during the run.

# %%
key = est.model_data.replace("s3://" + sess.default_bucket() + '/', '')

sess.boto_session.client("s3", region_name=sess.boto_region_name).download_file(
    Bucket=sess.default_bucket(), Key=key, Filename='model.tar.gz',
)

# %%
# !tar -xvzf model.tar.gz

# %%
# %tensorboard --logdir ./ --host 0.0.0.0
